# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = ["Me", "", " ", "  ", "   ", "    ", "     ", "      ", "       ", "        ", "American Discovery"]
y = [4, 1400, 1444, 2174, 2638, 3100, 4455, 4600, 5400, 6800, 6800]
plt.style.use('ggplot')

plt.bar(x, y)
plt.title("Trail length by Trail")
plt.ylabel("Trail length (mi)")
plt.xlabel("Trail")
plt.savefig("trails.png")
